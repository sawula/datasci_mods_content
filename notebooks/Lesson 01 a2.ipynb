# %% [markdown]
# ## ESPN's soccer shot charts (1)
#
# ESPN produces some unusual graphs for soccer games.  These are from a [game](https://www.espn.com/soccer/match/_/gameId/578282) between Sheffield United and Burnley on 23 May 2021.
#
# Pay attention to the representations of *shots* and *shots on goal*. Do you notice anything amiss with the areas?

# %% [markdown]
# ![ds0_9.png](attachment:ds0_9.png)

# %% [markdown]
# Redesign the rectangles representing shots and shots on goal for Sheffield and Burnley.  To simplify the task
# * make all of the rectangles squares
# * let the square representing Sheffield's shots on goal have sides of length 100
# * make the drawing window `400 200`

# %% [markdown]
# --------------------------
# When you are finished, submit a pdf of your notebook on Canvas.
