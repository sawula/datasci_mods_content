# %% [markdown]
# ## ESPN's soccer shot charts (2)
#
#
# ### A. Bars are better
# In the last notebook, we made a significant improvement to the ESPN shot charts for soccer games.  In your assignments, the areas of the squares should be in proportion to the number of shots.
#
# The trouble is: this is the wrong design for these quantities.
#
#
# Here's the issue.  The following figures represent fractional areas:  the first with squares and the second with rectangles of the same width.  Can you see how much easier it is to read the fractions in the second row of graphs?
#
# ![ds0_12.png](attachment:ds0_12.png)

# %% [markdown]
# ### B. Redesign shot chart with bars
# Now you try it!
#
# Represent shots/shots on goal from the Sheffield United (12,3) vs. Burnley (10,3) match using rectangles of the same width.

# %% [markdown]
# When you are finished, submit a pdf of your notebook on Canvas.
